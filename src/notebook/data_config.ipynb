# %% [markdown]
# # **Nex-Gen-Ai-Healthcare**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
precautions_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/Disease precaution.csv')
symptoms_df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/DiseaseAndSymptoms.csv')
description_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/Disease_Description.csv')
patiant_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/Disease_symptom_and_patient_profile_dataset.csv')
specailist_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/Doctor_Versus_Disease.csv', encoding='ISO-8859-1')

# %%
description_df.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
patiant_df.head()
# Out:
#        Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0    Influenza   Yes    No     Yes                  Yes   19  Female
# 1  Common Cold    No   Yes     Yes                   No   25  Female
# 2       Eczema    No   Yes     Yes                   No   25  Female
# 3       Asthma   Yes   Yes      No                  Yes   25    Male
# 4       Asthma   Yes   Yes      No                  Yes   25    Male
#
#   Blood Pressure Cholesterol Level Outcome Variable
# 0            Low            Normal         Positive
# 1         Normal            Normal         Negative
# 2         Normal            Normal         Negative
# 3         Normal            Normal         Positive
# 4         Normal            Normal         Positive

# %%
specailist_df.head()
# Out:
#    Drug Reaction      Allergist
# 0        Allergy      Allergist
# 1  Hypertension    Cardiologist
# 2   Heart attack   Cardiologist
# 3      Psoriasis  Dermatologist
# 4    Chicken pox  Dermatologist

# %%
precautions_df.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
symptoms_df.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
print(precautions_df.info())
print(description_df.info())
print(specailist_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Disease       41 non-null     object
#  1   Precaution_1  41 non-null     object
#  2   Precaution_2  41 non-null     object
#  3   Precaution_3  40 non-null     object
#  4   Precaution_4  40 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Disease      41 non-null     object
#  1   Description  41 non-null     object
# dtypes: object(2)
# memory usage: 784.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
# ...

# %%
outcome_df =pd.merge(precautions_df, description_df,on='Disease')

# %%
pred_df = pd.merge(patiant_df, symptoms_df,on='Disease')

# %%
outcome_df.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4  \
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths
#
#                                          Description
# 0  An adverse drug reaction (ADR) is an injury ca...
# ...

# %%
pred_df.sample(10)
# Out:
#               Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 2970         Migraine   Yes   Yes      No                   No   38    Male
# 6285   Hypothyroidism    No    No     Yes                   No   48    Male
# 2013  Gastroenteritis    No    No      No                   No   38    Male
# 1277  Hyperthyroidism   Yes   Yes     Yes                   No   35    Male
# 1693  Gastroenteritis   Yes   Yes     Yes                   No   30    Male
# 6690   Hypothyroidism    No    No     Yes                   No   55  Female
# 4557        Psoriasis   Yes    No      No                   No   35  Female
# 2730         Migraine    No   Yes     Yes                   No   35    Male
# 4574        Psoriasis    No   Yes     Yes                   No   35  Female
# 6159   Hypothyroidism    No    No     Yes                   No   45  Female
#
#      Blood Pressure Cholesterol Level Outcome Variable  ...  \
# 2970           High              High         Positive  ...
# ...

# %%
# pred_df.to_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/modeltraining_df.csv')

# %%
# outcome_df.to_csv('/content/drive/MyDrive/Colab Notebooks/NexGenAIHealthcare/suggestion_df.csv')
